# %%
import numpy as np

import torch
from torch import nn
from torch import optim

import tqdm

import tkinter

from IPython.display import clear_output

# %%
import sys
sys.path.append('..')

from samplers_new import mala, i_sir, ex2_mcmc

# %%
from cifar10_experiments.models import Generator, Discriminator

# %%
device = 'cpu'
lat_size=100

# %%
gen_cifar10 = Generator(lat_size)
gen_cifar10.to(device)

discr_cifar10 = Discriminator()
discr_cifar10.to(device)

prior_cifar10 = torch.distributions.MultivariateNormal(torch.zeros(lat_size).to(device), torch.eye(lat_size).to(device))

# %%
gen_cifar10.load_state_dict(torch.load('./weights/generator.pkl', map_location='cpu'))
discr_cifar10.load_state_dict(torch.load('./weights/discriminator.pkl', map_location='cpu'))
gen_cifar10.eval()
discr_cifar10.eval();

# %%
def get_energy_wgan(z):
    return (-discr_cifar10(gen_cifar10(z)).squeeze(dim=-1).squeeze(dim=-1).squeeze(dim=-1) - prior_cifar10.log_prob(z))

def log_target_dens(z, batch_size=None):
    """
    returns the value of a target density - mixture of the 3 gaussians 
    """
    if batch_size:
        results = []

        for i in range(z.shape[0] // batch_size + (1 if z.shape[0] % batch_size else 0)):
            cur_z = z[i * batch_size: (i + 1) * batch_size]
            results.append(-get_energy_wgan(cur_z))

        return torch.cat(results)
    else:
        return -get_energy_wgan(z)

# %%
log_target_dens(torch.randn(9, lat_size), batch_size=4)
# Out:
# tensor([-1546.9387, -1594.9951, -1552.6638, -1591.1522, -1630.0638, -1539.0603,
#         -1559.0632, -1564.1466, -1563.6500], grad_fn=<CatBackward0>)

# %% [markdown]
# ### Target energy

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
seed=42
torch.manual_seed(seed)
np.random.seed(seed)

N_samples = 10

x0 = torch.randn(N_samples, lat_size).to(device)

# %%
a = 2
N_pts = 10

plt.figure(figsize=(16, 16))

idxs = []
dens = []

for j in tqdm.tqdm(range(9)):
    idxs_perm = np.random.permutation(np.arange(lat_size))
    
    i1 = idxs_perm[0]
    i2 = idxs_perm[1]
    
    c1 = np.zeros(lat_size)
    c1[i1] = 1

    c2 = np.zeros(lat_size)
    c2[i2] = 1

    idxs.append((i1, i2))
    
    xlist = np.linspace(-2*a, 2*a, N_pts)
    ylist = np.linspace(-2*a, 2*a, N_pts)

    X, Y = np.meshgrid(xlist, ylist)
    points = np.zeros((X.shape[0],X.shape[1], 2),dtype=float)
    points[:, :, 0] = X
    points[:, :, 1] = Y

    points = points.reshape(-1, 2)
    z = points @ np.concatenate((c1[None, :], c2[None, :]))
    z = torch.FloatTensor(z).to(device)
    
    dens_vals = log_target_dens(z, batch_size=128).detach().cpu().numpy()
    dens_vals = dens_vals.reshape(N_pts, N_pts)
    
    dens.append(dens_vals)

    plt.subplot(3, 3, j+1)
    cp = plt.contourf(X, Y, dens_vals)
    plt.colorbar(cp) # Add a colorbar to a plot
    
    plt.xlabel(f'z_{i1}')
    plt.ylabel(f'z_{i2}')
    
plt.show()
# Out:
# 100%|█████████████████████████████████████████████| 9/9 [00:08<00:00,  1.12it/s]

# %% [markdown]
# # I-SIR

# %%
from torch.distributions import MultivariateNormal

sigma_isir = 1.0
isir_proposal = torch.distributions.MultivariateNormal(
    loc=torch.zeros(lat_size).to(device), 
    covariance_matrix=(sigma_isir ** 2) * torch.eye(lat_size).to(device))

# %%
N_steps=100
N_part=10

Samples_isir = i_sir(log_target_dens=log_target_dens, x0=x0, N_steps=N_steps, N_part=N_part, isir_proposal=isir_proposal, seed=seed)
# Out:
#  13%|█████▍                                    | 13/100 [00:12<01:23,  1.04it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 4>()
#       1 N_steps=100
#       2 N_part=10
# ----> 4 Samples_isir = i_sir(log_target_dens=log_target_dens, x0=x0, N_steps=N_steps, N_part=N_part, isir_proposal=isir_proposal, seed=seed)
#
# File ~/Desktop/projects/ex2mcmc_new/cifar10_experiments/../samplers_new.py:177, in i_sir(log_target_dens, x0, N_steps, N_part, isir_proposal, seed)
#     174 x_cur = x0
#     176 for _ in tqdm.tqdm(range(N_steps)):
# --> 177     x_cur = i_sir_step(log_target_dens, x_cur, N_part, isir_proposal)
#     178     samples_traj.append(x_cur)
#     180 samples_traj = torch.stack(samples_traj).transpose(0, 1)
#
# File ~/Desktop/projects/ex2mcmc_new/cifar10_experiments/../samplers_new.py:160, in i_sir_step(log_target_dens, x_cur, N_part, isir_proposal)
#     157 proposals[:, 0, :] = x_cur
#     159 # compute importance weights
# --> 160 logw = log_target_dens(proposals.reshape(-1, lat_size)).detach() - isir_proposal.log_prob(proposals.reshape(-1, lat_size))
#     161 logw = logw.reshape(N_samples, N_part)
#     163 #sample selected particle indexes
#
# Input In [7], in log_target_dens(z, batch_size)
#      10 for i in range(z.shape[0] // batch_size + (1 if z.shape[0] % batch_size else 0)):
#      11     cur_z = z[i * batch_size: (i + 1) * batch_size]
# ---> 12     results.append(-get_energy_wgan(cur_z))
#      14 return torch.cat(results)
#
# Input In [7], in get_energy_wgan(z)
#       1 def get_energy_wgan(z):
# ----> 2     return (-discr_cifar10(gen_cifar10(z)).squeeze(dim=-1).squeeze(dim=-1).squeeze(dim=-1) - prior_cifar10.log_prob(z))
#
# File ~/.anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Desktop/projects/ex2mcmc_new/cifar10_experiments/../cifar10_experiments/models/wgan.py:43, in Generator.forward(self, x)
#      42 def forward(self, x):
# ---> 43     x = self.main_module(x[:, :, None, None])
#      44     return self.output(x)
#
# File ~/.anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.anaconda3/lib/python3.9/site-packages/torch/nn/modules/container.py:141, in Sequential.forward(self, input)
#     139 def forward(self, input):
#     140     for module in self:
# --> 141         input = module(input)
#     142     return input
#
# File ~/.anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.anaconda3/lib/python3.9/site-packages/torch/nn/modules/conv.py:925, in ConvTranspose2d.forward(self, input, output_size)
#     920 # One cannot replace List by Tuple or Sequence in "_output_padding" because
#     921 # TorchScript does not support `Sequence[T]` or `Tuple[T, ...]`.
#     922 output_padding = self._output_padding(
#     923     input, output_size, self.stride, self.padding, self.kernel_size, self.dilation)  # type: ignore[arg-type]
# --> 925 return F.conv_transpose2d(
#     926     input, self.weight, self.bias, self.stride, self.padding,
#     927     output_padding, self.groups, self.dilation)
#
# KeyboardInterrupt:

# %%
energies_isir = -log_target_dens(Samples_isir.reshape(-1, lat_size)).reshape(N_samples, N_steps + 1).detach().cpu().numpy()

# %%
a = 2

plt.figure(figsize=(16, 16))

for j in tqdm.tqdm(range(9)):
    i1, i2 = idxs[j]
    
    N_pts = 10
    xlist = np.linspace(-2*a, 2*a, N_pts)
    ylist = np.linspace(-2*a, 2*a, N_pts)

    X, Y = np.meshgrid(xlist, ylist)

    dens_vals = dens[j]

    plt.subplot(3, 3, j+1)
    cp = plt.contourf(X, Y, dens_vals)
    plt.colorbar(cp) # Add a colorbar to a plot
    
    x = Samples_isir[0, :, i1].cpu().numpy()
    y = Samples_isir[0, :, i2].cpu().numpy()
    
    plt.quiver(x[:-1], y[:-1], x[1:]-x[:-1], y[1:]-y[:-1], scale_units='xy', angles='xy', scale=1, color='red')
    plt.title('i-SIR samples')
    
    plt.xlabel(f'z_{i1}')
    plt.ylabel(f'z_{i2}')
    
plt.show()
# Out:
# 100%|█████████████████████████████████████████████| 9/9 [00:00<00:00, 64.08it/s]

# %%
plt.figure(figsize=(15, 15))

for traj_i in range(10):
    for step_i in range(10):
        plt.subplot(10, 10, 10 * traj_i + step_i + 1)
        img = gen_cifar10(torch.FloatTensor(Samples_isir[traj_i, step_i * 10:step_i * 10 + 1]))[0].detach().cpu().numpy()
        img = (img + 1) / 2
        
        plt.axis('off')
        plt.imshow(img.transpose((1, 2, 0)))

# %%
means = energies_isir.mean(axis=0)
stds = energies_isir.std(axis=0)

plt.plot(np.arange(N_steps + 1), means, c='r')
plt.fill_between(np.arange(N_steps + 1), means - stds, means + stds, alpha=0.3)

# %% [markdown]
# # MALA

# %%
### sample mala
N_traj = 10
N_steps = 100

gamma = 5e-3
mala_iters = 3

n_accepts = 0

Samples_mala = mala(log_target_dens=log_target_dens, x0=x0, N_steps=N_steps, gamma=gamma, mala_iters=mala_iters, n_accepts=n_accepts, seed=42)
    
print("number accepts = ",n_accepts)
# Out:
# 100%|█████████████████████████████████████████| 100/100 [02:37<00:00,  1.58s/it]
# number accepts =  0

# %%
energies_mala = -log_target_dens(Samples_mala.reshape(-1, lat_size)).reshape(N_samples, N_steps + 1).detach().cpu().numpy()

# %%
a = 2

plt.figure(figsize=(16, 16))

for j in tqdm.tqdm(range(9)):
    i1, i2 = idxs[j]
    
    N_pts = 10
    xlist = np.linspace(-2*a, 2*a, N_pts)
    ylist = np.linspace(-2*a, 2*a, N_pts)

    X, Y = np.meshgrid(xlist, ylist)

    dens_vals = dens[j]

    plt.subplot(3, 3, j+1)
    cp = plt.contourf(X, Y, dens_vals)
    plt.colorbar(cp) # Add a colorbar to a plot
    
    x = Samples_mala[0, :, i1].cpu().numpy()
    y = Samples_mala[0, :, i2].cpu().numpy()
    
    plt.quiver(x[:-1], y[:-1], x[1:]-x[:-1], y[1:]-y[:-1], scale_units='xy', angles='xy', scale=1, color='red')
    plt.title('MALA samples')
    
    plt.xlabel(f'z_{i1}')
    plt.ylabel(f'z_{i2}')
    
plt.show()
# Out:
# 100%|█████████████████████████████████████████████| 9/9 [00:00<00:00, 78.94it/s]

# %%
plt.figure(figsize=(15, 15))

for traj_i in range(10):
    for step_i in range(10):
        plt.subplot(10, 10, 10 * traj_i + step_i + 1)
        img = gen_cifar10(torch.FloatTensor(Samples_mala[traj_i, step_i * 10:step_i * 10 + 1]))[0].detach().cpu().numpy()
        img = (img + 1) / 2
        
        plt.axis('off')
        plt.imshow(img.transpose((1, 2, 0)))

# %%
means = energies_mala.mean(axis=0)
stds = energies_mala.std(axis=0)

plt.plot(np.arange(N_steps + 1), means, c='r')
plt.fill_between(np.arange(N_steps + 1), means - stds, means + stds, alpha=0.3)

# %%
### sample mala
N_traj = 10

N_part=10

N_steps = 100


sigma_isir = 1.0
isir_proposal = torch.distributions.MultivariateNormal(
    loc=torch.zeros(lat_size).to(device), 
    covariance_matrix=(sigma_isir ** 2) * torch.eye(lat_size).to(device))


gamma = 5e-3
mala_iters = 3

n_accepts = 0

Samples_ex2 = ex2_mcmc(log_target_dens, x0, N_part, isir_proposal ,gamma,mala_iters, n_accepts=None, seed=42)
# Out:
# 100%|█████████████████████████████████████████| 100/100 [10:57<00:00,  6.57s/it]
# number accepts =  0

# %%
a = 2

plt.figure(figsize=(16, 16))

for j in tqdm.tqdm(range(9)):
    i1, i2 = idxs[j]
    
    N_pts = 10
    xlist = np.linspace(-2*a, 2*a, N_pts)
    ylist = np.linspace(-2*a, 2*a, N_pts)

    X, Y = np.meshgrid(xlist, ylist)

    dens_vals = dens[j]

    plt.subplot(3, 3, j+1)
    cp = plt.contourf(X, Y, dens_vals)
    plt.colorbar(cp) # Add a colorbar to a plot
    
    plt.scatter(Samples_ex2[1, :, i1], Samples_ex2[1, :, i2], s=1, c='r')
    plt.title('Ex2 samples')
    
    plt.xlabel(f'z_{i1}')
    plt.ylabel(f'z_{i2}')
    
plt.show()
# Out:
# 100%|█████████████████████████████████████████████| 9/9 [00:00<00:00, 25.51it/s]

# %%
plt.figure(figsize=(15, 15))

for traj_i in range(10):
    for step_i in range(10):
        plt.subplot(10, 10, 10 * traj_i + step_i + 1)
        img = gen_cifar10(torch.FloatTensor(Samples_ex2[traj_i, step_i * 10:step_i * 10 + 1]))[0].detach().cpu().numpy()
        img = (img + 1) / 2
        
        plt.axis('off')
        plt.imshow(img.transpose((1, 2, 0)))

# %%
means = np.array([e.mean() for e in energies_ex2])
stds = np.array([e.std() for e in energies_ex2])

plt.plot(np.arange(N_steps), means, c='r')
plt.fill_between(np.arange(N_steps), means - stds, means + stds, alpha=0.3)

# %% [markdown]
# ### Plot all 3 pictures together

# %%
a = 2

plt.figure(figsize=(16, 16))

for j in tqdm.tqdm(range(9)):
    i1, i2 = idxs[j]
    
    N_pts = 10
    xlist = np.linspace(-2*a, 2*a, N_pts)
    ylist = np.linspace(-2*a, 2*a, N_pts)

    X, Y = np.meshgrid(xlist, ylist)

    dens_vals = dens[j]

    plt.subplot(3, 3, j+1)
    cp = plt.contourf(X, Y, dens_vals)
    plt.colorbar(cp) # Add a colorbar to a plot
    
    plt.scatter(Samples_ex2[0, :, i1], Samples_ex2[0, :, i2],  c='r', marker='.', label='Ex2MCMC') 
    plt.scatter(Samples_mala[0, :, i1], Samples_mala[0, :, i2], c='b', marker='x', label='MALA')
    plt.scatter(Samples_isir[0, :, i1], Samples_isir[0, :, i2], c='g', marker='^', label='I-SIR')
    
    plt.legend()
    
    plt.title('Samples')
    
    plt.xlabel(f'z_{i1}')
    plt.ylabel(f'z_{i2}')
    
plt.show()
# Out:
# 100%|█████████████████████████████████████████████| 9/9 [00:00<00:00, 29.51it/s]

# %%
means = np.array([e.mean() for e in energies_ex2])
stds = np.array([e.std() for e in energies_ex2])

plt.plot(np.arange(N_steps), means, c='r', label='Ex2MCMC')
#plt.fill_between(np.arange(N_steps), means - stds, means + stds, color='r', alpha=0.2)


means = np.array([e.mean() for e in energies_mala])
stds = np.array([e.std() for e in energies_mala])

plt.plot(np.arange(N_steps), means, c='b', label='MALA')
#plt.fill_between(np.arange(N_steps), means - stds, means + stds, color='b', alpha=0.2)

means = np.array([e.mean() for e in energies_isir])
stds = np.array([e.std() for e in energies_isir])

plt.plot(np.arange(N_steps), means, c='g', label='I-SIR')
#plt.fill_between(np.arange(N_steps), means - stds, means + stds, color='g', alpha=0.2)



plt.legend()
