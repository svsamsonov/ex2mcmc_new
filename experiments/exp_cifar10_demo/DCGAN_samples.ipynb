# %%
from pathlib import Path
import tqdm
import numpy as np
import torch
from torch.distributions import MultivariateNormal
import matplotlib.pyplot as plt

from torch_mimicry.nets import dcgan
from ex2mcmc.old_samplers import mala, i_sir, ex2mcmc, flex2mcmc
from ex2mcmc.models.rnvp_minimal import MinimalRNVP
from ex2mcmc.utils import CHECKPOINT_DIR
# Out:
# 2023-04-16 01:38:24.568931: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
lat_size=128

# %%
gen_cifar10 = dcgan.DCGANGenerator32().to(device)
gen_cifar10.to(device)

discr_cifar10 =  dcgan.DCGANDiscriminator32().to(device)
discr_cifar10.to(device)

prior_cifar10 = torch.distributions.MultivariateNormal(torch.zeros(lat_size).to(device), torch.eye(lat_size).to(device))

# %%
gen_cifar10.load_state_dict(torch.load(Path(CHECKPOINT_DIR, 'CIFAR10/DCGAN_NS/netG_100000_steps.pth'), map_location='cpu')['model_state_dict'])
discr_cifar10.load_state_dict(torch.load(Path(CHECKPOINT_DIR, 'CIFAR10/DCGAN_NS/netD_100000_steps.pth'), map_location='cpu')['model_state_dict'])
gen_cifar10.eval()
discr_cifar10.eval();

# %%
def get_energy(z):
    return -discr_cifar10(gen_cifar10(z)).reshape(z.shape[0]) - prior_cifar10.log_prob(z)

def log_target_dens(z, detach=False, batch_size=128):
    """
    returns the value of a target density - mixture of the 3 gaussians 
    """
    res = []
    for i in range(z.shape[0] // batch_size + (1 if z.shape[0] % batch_size else 0)):
        cur_res = -get_energy(z[batch_size * i: batch_size * (i+1)])
        
        if detach:
            cur_res = cur_res.detach()
        
        res.append(cur_res)
    
    return torch.cat(res)

# %%
log_target_dens(torch.randn(100, lat_size)).std()
# Out:
# tensor(10.0822)

# %% [markdown]
# # Put parameters of the target density

# %%
seed = 42
torch.manual_seed(42)

N_samples=50000

x0 = torch.randn(N_samples, lat_size).to(device)

# %%
a = 2

fig = plt.figure(figsize=(16, 16))

idxs = []
dens = []

for j in tqdm.tqdm(range(9)):
    idxs_perm = np.random.permutation(np.arange(lat_size))
    
    i1 = idxs_perm[0]
    i2 = idxs_perm[1]
    
    c1 = torch.zeros(lat_size).to(device)
    c1[i1] = 1

    c2 = torch.zeros(lat_size).to(device)
    c2[i2] = 1

    idxs.append((i1, i2))
    
    N_pts = 10
    xlist = np.linspace(-2*a, 2*a, N_pts)
    ylist = np.linspace(-2*a, 2*a, N_pts)

    X, Y = np.meshgrid(xlist, ylist)
    points = np.zeros((X.shape[0],X.shape[1], 2),dtype=float)
    points[:, :, 0] = X
    points[:, :, 1] = Y

    points = points.reshape(-1, 2)
    points = torch.FloatTensor(points).to(device)
    
    z = points @ torch.stack((c1, c2))
    
    dens_vals = log_target_dens(z).detach().cpu().numpy()
    
    dens_vals = dens_vals.reshape(N_pts, N_pts)
    
    dens.append(dens_vals)

    plt.subplot(3, 3, j+1)
    cp = plt.contourf(X, Y, dens_vals)
    plt.colorbar(cp) # Add a colorbar to a plot
    
    plt.xlabel(f'z_{i1}')
    plt.ylabel(f'z_{i2}')
    
fig.tight_layout()    
plt.show()
# Out:
# 100%|██████████| 9/9 [00:47<00:00,  5.23s/it]

# %% [markdown]
# # I-SIR

# %%
sigma_isir = 1.0
isir_proposal = MultivariateNormal(
    torch.zeros(lat_size).to(device), 
    (sigma_isir ** 2) * torch.eye(lat_size).to(device))

N_particles = 10
N_steps = 100

Samples_isir = i_sir(log_target_dens=log_target_dens, x0=x0, N_steps=N_steps, N_part=N_particles, isir_proposal=isir_proposal)

energies_isir = -log_target_dens(Samples_isir.reshape(-1, lat_size)).reshape(N_samples, N_steps + 1).cpu()
# Out:
#   0%|          | 0/100 [00:06<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 9
#       6 N_particles = 10
#       7 N_steps = 100
# ----> 9 Samples_isir = i_sir(log_target_dens=log_target_dens, x0=x0, N_steps=N_steps, N_part=N_particles, isir_proposal=isir_proposal)
#      11 energies_isir = -log_target_dens(Samples_isir.reshape(-1, lat_size)).reshape(N_samples, N_steps + 1).cpu()
#
# File ~/ex2mcmc/ex2mcmc/samplers.py:323, in i_sir(log_target_dens, x0, N_steps, N_part, isir_proposal, seed)
#     320 x_cur = x0
#     322 for _ in tqdm.tqdm(range(N_steps)):
# --> 323     x_cur = i_sir_step(log_target_dens, x_cur, N_part, isir_proposal)
#     324     samples_traj.append(x_cur)
#     326 samples_traj = torch.stack(samples_traj).transpose(0, 1)
#
# File ~/ex2mcmc/ex2mcmc/samplers.py:259, in i_sir_step(log_target_dens, x_cur, N_part, isir_proposal, return_all_stats)
#     256 proposals = torch.cat((x_cur[:, None, :], proposals), dim=1)
#     258 # compute importance weights
# --> 259 log_target_dens_proposals = log_target_dens(
#     260     proposals.reshape(-1, lat_size)
#     261 ).reshape(N_samples, N_part)
#     263 logw = log_target_dens_proposals - isir_proposal.log_prob(proposals)
#     265 # sample selected particle indexes
#
# Cell In[5], line 10, in log_target_dens(z, detach, batch_size)
#       8 res = []
#       9 for i in range(z.shape[0] // batch_size + (1 if z.shape[0] % batch_size else 0)):
# ---> 10     cur_res = -get_energy_wgan(z[batch_size * i: batch_size * (i+1)])
#      12     if detach:
#      13         cur_res = cur_res.detach()
#
# Cell In[5], line 2, in get_energy_wgan(z)
#       1 def get_energy_wgan(z):
# ----> 2     return -discr_cifar10(gen_cifar10(z)).reshape(z.shape[0]) - prior_cifar10.log_prob(z)
#
# File ~/miniconda3/envs/ex2mcmc/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/ex2mcmc/lib/python3.8/site-packages/torch_mimicry/nets/dcgan/dcgan_32.py:54, in DCGANGenerator32.forward(self, x)
#      52 h = self.b5(h)
#      53 h = self.activation(h)
# ---> 54 h = torch.tanh(self.c5(h))  # tanh
#      56 return h
#
# File ~/miniconda3/envs/ex2mcmc/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/ex2mcmc/lib/python3.8/site-packages/torch/nn/modules/conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/ex2mcmc/lib/python3.8/site-packages/torch/nn/modules/conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
a = 2

fig = plt.figure(figsize=(16, 16))

for j in tqdm.tqdm(range(9)):
    i1, i2 = idxs[j]
    
    N_pts = 10
    xlist = np.linspace(-2*a, 2*a, N_pts)
    ylist = np.linspace(-2*a, 2*a, N_pts)

    X, Y = np.meshgrid(xlist, ylist)

    dens_vals = dens[j]

    plt.subplot(3, 3, j+1)
    cp = plt.contourf(X, Y, dens_vals)
    plt.colorbar(cp) # Add a colorbar to a plot
    
    plt.scatter(Samples_isir[0, :, i1].cpu().numpy(), Samples_isir[0, :, i2].cpu().numpy(), s=1, c='r')
    plt.title('i_SIR samples')
    
    plt.xlabel(f'z_{i1}')
    plt.ylabel(f'z_{i2}')
    
fig.tight_layout()  
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 76.39it/s]

# %%
plt.figure(figsize=(15, 15))

for traj_i in range(10):
    for step_i in range(10):
        plt.subplot(10, 10, 10 * traj_i + step_i + 1)
        img = gen_cifar10(torch.randn(1, 128))[0].detach().cpu().numpy()
        #img = gen_cifar10(torch.FloatTensor(Samples_isir[traj_i, step_i * 10:step_i * 10 + 1]))[0].detach().cpu().numpy()
        img = (img + 1) / 2
        
        plt.axis('off')
        plt.imshow(img.transpose((1, 2, 0)))

# %%
means = energies_isir.mean(dim=0)
stds = energies_isir.std(dim=0)

plt.plot(np.arange(N_steps + 1), means, c='r')
plt.fill_between(np.arange(N_steps + 1), means - stds, means + stds, alpha=0.3)

# %% [markdown]
# # MALA

# %%
N_steps = 100

gamma = 1e-3
mala_iters = 3

stats = {'n_accepts': 0}

Samples_mala = mala(log_target_dens=log_target_dens, x0=x0, N_steps=N_steps, gamma=gamma, mala_iters=mala_iters, stats=stats)

energies_mala = -log_target_dens(Samples_mala.reshape(-1, lat_size)).reshape(N_samples, N_steps + 1).cpu()

# %%
stats

# %%
a = 2

fig = plt.figure(figsize=(16, 16))

for j in tqdm.tqdm(range(9)):
    i1, i2 = idxs[j]
    
    N_pts = 10
    xlist = np.linspace(-2*a, 2*a, N_pts)
    ylist = np.linspace(-2*a, 2*a, N_pts)

    X, Y = np.meshgrid(xlist, ylist)

    dens_vals = dens[j]

    plt.subplot(3, 3, j+1)
    cp = plt.contourf(X, Y, dens_vals)
    plt.colorbar(cp) # Add a colorbar to a plot
    
    plt.scatter(Samples_mala[0, :, i1].cpu().numpy(), Samples_mala[0, :, i2].cpu().numpy(), s=1, c='r')
    plt.title('MALA samples')
    
    plt.xlabel(f'z_{i1}')
    plt.ylabel(f'z_{i2}')
    
fig.tight_layout()  
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 78.43it/s]

# %%
plt.figure(figsize=(15, 15))

for traj_i in range(10):
    for step_i in range(10):
        plt.subplot(10, 10, 10 * traj_i + step_i + 1)
        img = gen_cifar10(torch.FloatTensor(Samples_mala[traj_i, step_i * 10:step_i * 10 + 1]))[0].detach().cpu().numpy()
        img = (img + 1) / 2
        
        plt.axis('off')
        plt.imshow(img.transpose((1, 2, 0)))

# %%
means = energies_mala.mean(dim=0)
stds = energies_mala.std(dim=0)

plt.plot(np.arange(N_steps + 1), means, c='r')
plt.fill_between(np.arange(N_steps + 1), means - stds, means + stds, alpha=0.3)

# %% [markdown]
# # Ex2MCMC

# %%
N_steps = 100

sigma_isir = 1.0
isir_proposal = MultivariateNormal(
    torch.zeros(lat_size).to(device), 
    (sigma_isir ** 2) * torch.eye(lat_size).to(device))

N_particles = 10

gamma = 5e-3
mala_iters = 3

n_accepts = 0

Samples_ex2 = ex2mcmc(log_target_dens=log_target_dens, x0=x0, N_steps=N_steps, 
                       N_part=N_particles, isir_proposal=isir_proposal ,
                       gamma=gamma, mala_iters=mala_iters, n_accepts=n_accepts)

energies_ex2 = -log_target_dens(Samples_ex2.reshape(-1, lat_size)).reshape(N_samples, N_steps + 1).cpu()

# %%
a = 2

plt.figure(figsize=(16, 16))

for j in tqdm.tqdm(range(9)):
    i1, i2 = idxs[j]
    
    N_pts = 10
    xlist = np.linspace(-2*a, 2*a, N_pts)
    ylist = np.linspace(-2*a, 2*a, N_pts)

    X, Y = np.meshgrid(xlist, ylist)

    dens_vals = dens[j]

    plt.subplot(3, 3, j+1)
    cp = plt.contourf(X, Y, dens_vals)
    plt.colorbar(cp) # Add a colorbar to a plot
    
    plt.scatter(Samples_ex2[0, :, i1].cpu().numpy(), Samples_ex2[0, :, i2].cpu().numpy(), s=1, c='r')
    plt.title('Ex2 samples')
    
    plt.xlabel(f'z_{i1}')
    plt.ylabel(f'z_{i2}')
    
plt.show()

# %%
plt.figure(figsize=(15, 15))

for traj_i in range(10):
    for step_i in range(10):
        plt.subplot(10, 10, 10 * traj_i + step_i + 1)
        img = gen_cifar10(torch.FloatTensor(Samples_ex2[traj_i, step_i * 10:step_i * 10 + 1]))[0].detach().cpu().numpy()
        img = (img + 1) / 2
        
        plt.axis('off')
        plt.imshow(img.transpose((1, 2, 0)))

# %%
means = energies_ex2.mean(dim=0)
stds = energies_ex2.std(dim=0)

plt.plot(np.arange(N_steps + 1), means, c='r')
plt.fill_between(np.arange(N_steps + 1), means - stds, means + stds, alpha=0.3)

# %% [markdown]
# ### Plot all 3 pictures together

# %%
a = 2

fig = plt.figure(figsize=(16, 16))

for j in tqdm.tqdm(range(9)):
    i1, i2 = idxs[j]
    
    N_pts = 10
    xlist = np.linspace(-2*a, 2*a, N_pts)
    ylist = np.linspace(-2*a, 2*a, N_pts)

    X, Y = np.meshgrid(xlist, ylist)

    dens_vals = dens[j]

    plt.subplot(3, 3, j+1)
    cp = plt.contourf(X, Y, dens_vals)
    plt.colorbar(cp) # Add a colorbar to a plot
    
    plt.scatter(Samples_ex2[0, :, i1], Samples_ex2[0, :, i2],  c='r', marker='.', label='Ex2MCMC') 
    plt.scatter(Samples_mala[0, :, i1], Samples_mala[0, :, i2], c='b', marker='x', label='MALA')
    plt.scatter(Samples_isir[0, :, i1], Samples_isir[0, :, i2], c='g', marker='^', label='I-SIR')
    
    plt.legend()
    
    plt.title('Samples')
    
    plt.xlabel(f'z_{i1}')
    plt.ylabel(f'z_{i2}')
    
fig.tight_layout()  
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:00<00:00, 26.89it/s]

# %%
means = energies_ex2.mean(dim=0)
stds = energies_ex2.std(dim=0)

plt.plot(np.arange(N_steps + 1), means, c='r', label='Ex2MCMC')
#plt.fill_between(np.arange(N_steps), means - stds, means + stds, color='r', alpha=0.2)


means = energies_mala.mean(dim=0)
stds = energies_mala.std(dim=0)

plt.plot(np.arange(N_steps + 1), means, c='b', label='MALA')
#plt.fill_between(np.arange(N_steps), means - stds, means + stds, color='b', alpha=0.2)

means = energies_isir.mean(dim=0)
stds = energies_isir.std(dim=0)

plt.plot(np.arange(N_steps + 1), means, c='g', label='I-SIR')
#plt.fill_between(np.arange(N_steps), means - stds, means + stds, color='g', alpha=0.2)



plt.legend()

# %%
#adaptive i-sir

N_try = 5
energies_all_flex = []
samples_all_flex = []

for i in range(N_try):
    seed = 42+i
    torch.manual_seed(seed)

    N_samples=100

    x0 = torch.randn(N_samples, lat_size).to(device)

    isir_proposal = MinimalRNVP(lat_size=lat_size,device=device).to(device)

    proposal_opt = torch.optim.Adam(isir_proposal.parameters(), lr=1e-3)

    for _ in tqdm.tqdm(range(50)):
        proposal_opt.zero_grad()
        loss = -isir_proposal.log_prob(torch.randn(1000, lat_size).to(device)).mean()
        loss.backward()
        proposal_opt.step()
    
    N_steps = 100

    sigma_isir = 1.0
    N_particles = 10

    gamma = 1e-3
    mala_iters = 3

    stats = {'n_accepts': 0}

    Samples_flex2 = flex2mcmc(log_target_dens=log_target_dens, x0=x0, N_steps=N_steps, 
                       N_part=N_particles, isir_proposal=isir_proposal ,
                       gamma=gamma, mala_iters=mala_iters, stats=stats)

    energies_flex2 = -log_target_dens(Samples_flex2.reshape(-1, lat_size)).reshape(N_samples, N_steps + 1).cpu()
    energies_all_flex.append(energies_flex2.numpy())
    samples_all_flex.append(Samples_flex2.cpu().numpy())
